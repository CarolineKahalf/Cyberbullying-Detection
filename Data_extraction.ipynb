# %% [markdown]
# <a href="https://colab.research.google.com/github/CarolineKahalf/Cyberbullying-Detection/blob/main/Data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import json
import tweepy
import numpy as np
import pandas as pd
import re

# %%
consumer_key="PY0qboXXtlYPm9aw8j4QE1syx"
consumer_secret="wjvJ08CDX0xoSY5iv1YUt4flUql5mGNEDRhBryQ0CybFAXYJfg"   
access_token="1409807449209589761-8xf1V8BZ3zO9OhNjKWBQEuJmkJxMCY"
access_token_secret="FvNWtGWpr36kHY6nuBCV3CkIKEgb4es4XTFx5qwUJXKYV"

# %%
auth = tweepy.OAuthHandler(consumer_key="PY0qboXXtlYPm9aw8j4QE1syx", consumer_secret="wjvJ08CDX0xoSY5iv1YUt4flUql5mGNEDRhBryQ0CybFAXYJfg")
auth.access_token="1409807449209589761-8xf1V8BZ3zO9OhNjKWBQEuJmkJxMCY"
auth.access_token_secret="FvNWtGWpr36kHY6nuBCV3CkIKEgb4es4XTFx5qwUJXKYV"

# %%
# any query words
query_words = ['racism','hate','ugly','stupid','idiot', 'whore', 'fuck', 'ignorant','suicide','kill','murder','weak','excellent','best','nice','smart','good', 'love','beautiful'] 
api = tweepy.API(auth, wait_on_rate_limit=True)
for i in range(len(query_words)):
    search = tweepy.Cursor(api.search, q = query_words[i], 
                       tweet_mode = 'extended', # length of tweet text
                       include_rts = True, # to include retweets
                       lang = "en").items(4000) # any number of tweets- up to about 4000
    
    all_data = []
    for tweet in search:
        status = tweet
        all_data.append(tweet._json)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-1b1dd2514b8f> in <module>()
#       9
#      10     all_data = []
# ---> 11     for tweet in search:
#      12         status = tweet
#      13         all_data.append(tweet._json)
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# /usr/local/lib/python3.7/dist-packages/tweepy/cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# ...

# %%
all_data

# %%
len(all_data)
# Out:
# 2203

# %%
df=pd.DataFrame(all_data)
df
# Out:
#                           created_at  ...  quoted_status
# 0     Fri Oct 22 10:41:53 +0000 2021  ...            NaN
# 1     Fri Oct 22 10:41:51 +0000 2021  ...            NaN
# 2     Fri Oct 22 10:41:51 +0000 2021  ...            NaN
# 3     Fri Oct 22 10:41:44 +0000 2021  ...            NaN
# 4     Fri Oct 22 10:41:43 +0000 2021  ...            NaN
# ...                              ...  ...            ...
# 2198  Fri Oct 22 09:36:27 +0000 2021  ...            NaN
# 2199  Fri Oct 22 09:36:27 +0000 2021  ...            NaN
# 2200  Fri Oct 22 09:36:24 +0000 2021  ...            NaN
# 2201  Fri Oct 22 09:36:24 +0000 2021  ...            NaN
# 2202  Fri Oct 22 09:36:23 +0000 2021  ...            NaN
#
# [2203 rows x 31 columns]

# %%
df.to_csv('uncleanData5.csv', index=False)
